# %% [markdown]
# <a href="https://colab.research.google.com/github/Sohamkantijana/LGMDataScience/blob/main/TAsk4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Image to Pencil Sketch Using Python
# Explanation:
#
#
# Firstly, load the Image in python.
# Then converted the image to grayscale.
# Then invert the image.
# Next apply Gaussian Blur.
# Finish it by douging and burning then converting the image to a Pencil Sketch.

# %% [markdown]
# ![desktop-wallpaper-roronoa-zoro-by-portgasdbrand-zoro-dark-thumbnail.jpg](data:image/jpeg;base64,...)

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('/content/desktop-wallpaper-roronoa-zoro-by-portgasdbrand-zoro-dark-thumbnail.jpg',0)

# %%
print('Minimum color range',img.min())
print('Maximum color range',img.max())
# Out:
# Minimum color range 0
# Maximum color range 255

# %% [markdown]
# Conert into Grayscale

# %%
plt.imshow(img,cmap='gray')
plt.title('Black and white imege')
plt.show()

# %% [markdown]
# INVERTING THE IMAGE

# %%
inv=255-img
plt.title('Inverted imege')
plt.imshow(inv,cmap='gray')
plt.show()

# %% [markdown]
# GAUSSIAN BLUR

# %%
gblur=cv2.GaussianBlur(inv,ksize=(21,21),sigmaX=0,sigmaY=0)
plt.title('Imege after Gaussian blur applied')
plt.imshow(gblur,cmap='gray')
plt.show()

# %% [markdown]
# DOUGING AND BURNING

# %%
dodge= lambda image,mask: cv2.divide(image,255-mask,scale=256)
blended=dodge(img,gblur)
plt.title('Pencil sketch of image')
plt.imshow(blended,cmap='gray')
plt.show()
